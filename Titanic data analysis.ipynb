# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #

# %% [markdown]
# # column types
# ## => numerical
# ## => categorical
# ## => mixed

# %% [markdown]
# # univariate analysis of numeric data

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# agar skew ki value 0 ke aas pas h, to data normally distribbuted h
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# 88   female  23.0      3      2     19950  263.0000      C23 C25 C27        S
# 258  female  35.0      0      0  PC 17755  512.3292              NaN        C
# 311  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 341  female  24.0      3      2     19950  263.0000      C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000      C23 C25 C27        S
# 679    male  36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292             B101        C
# 742  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # univariate analysis of catagorical data
#  survived,Pclass, sibsp

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct =' %0.1f%%')
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['SibSp'].value_counts().plot(kind='pie',autopct =' %0.1f%%')
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %% [markdown]
# # steps of doing bivariate analysis
# numerical-numerical
#
# numerical-categorical
#
# categorical-categorical

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.crosstab(df['Survived'], df['Pclass'], normalize='columns') *100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['Pclass'], normalize='columns') *100)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df['Survived'], df['Sex'], normalize='columns') *100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df['Survived'], df['Embarked'])
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize='columns') *100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns') *100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
#  numeric and categorical
# survived and age

# %%
df[df['Survived'] == 1]['Age'].plot(kind='kde', label='survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde', label='not-survived')

plt.legend()
plt.show()

# %%
# feature engineering on fare col

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# 846  NaN      8      2  CA. 2343  69.55   NaN        S
# 863  NaN      8      2  CA. 2343  69.55   NaN        S

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# 846  NaN      8      2  CA. 2343  69.55   NaN        S
# 863  NaN      8      2  CA. 2343  69.55   NaN        S

# %%
df1 = pd.read_csv('test.csv')

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df = pd.concat([df1, df])

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived
# 0      male  34.5      0      0      330911   7.8292   NaN        Q       NaN
# 1    female  47.0      1      0      363272   7.0000   NaN        S       NaN
# 2      male  62.0      0      0      240276   9.6875   NaN        Q       NaN
# 3      male  27.0      0      0      315154   8.6625   NaN        S       NaN
# 4    female  22.0      1      1     3101298  12.2875   NaN        S       NaN
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 886    male  27.0      0      0      211536  13.0000   NaN        S       0.0
# 887  female  19.0      0      0      112053  30.0000   B42        S       1.0
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S       0.0
# 889    male  26.0      0      0      111369  30.0000  C148        C       1.0
# 890    male  32.0      0      0      370376   7.7500   NaN        Q       0.0
#
# [1727 rows x 12 columns]

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Pclass                               Name     Sex   Age  \
# 188         1080       3                    Sage, Miss. Ada  female   NaN
# 342         1234       3              Sage, Mr. John George    male   NaN
# 360         1252       3        Sage, Master. William Henry    male  14.5
# 365         1257       3     Sage, Mrs. John (Annie Bullen)  female   NaN
# 188         1080       3                    Sage, Miss. Ada  female   NaN
# 342         1234       3              Sage, Mr. John George    male   NaN
# 360         1252       3        Sage, Master. William Henry    male  14.5
# 365         1257       3     Sage, Mrs. John (Annie Bullen)  female   NaN
# 159          160       3         Sage, Master. Thomas Henry    male   NaN
# 180          181       3       Sage, Miss. Constance Gladys  female   NaN
# 201          202       3                Sage, Mr. Frederick    male   NaN
# 324          325       3           Sage, Mr. George John Jr    male   NaN
# 792          793       3            Sage, Miss. Stella Anna  female   NaN
# 846          847       3           Sage, Mr. Douglas Bullen    male   NaN
# 863          864       3  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked  Survived
# 188      8      2  CA. 2343  69.55   NaN        S       NaN
# 342      1      9  CA. 2343  69.55   NaN        S       NaN
# 360      8      2  CA. 2343  69.55   NaN        S       NaN
# 365      1      9  CA. 2343  69.55   NaN        S       NaN
# 188      8      2  CA. 2343  69.55   NaN        S       NaN
# 342      1      9  CA. 2343  69.55   NaN        S       NaN
# 360      8      2  CA. 2343  69.55   NaN        S       NaN
# 365      1      9  CA. 2343  69.55   NaN        S       NaN
# 159      8      2  CA. 2343  69.55   NaN        S       0.0
# 180      8      2  CA. 2343  69.55   NaN        S       0.0
# 201      8      2  CA. 2343  69.55   NaN        S       0.0
# 324      8      2  CA. 2343  69.55   NaN        S       0.0
# 792      8      2  CA. 2343  69.55   NaN        S       0.0
# 846      8      2  CA. 2343  69.55   NaN        S       0.0
# 863      8      2  CA. 2343  69.55   NaN        S       0.0

# %%
df['Ticket'].value_counts()
# Out:
# CA. 2343        15
# PC 17608        12
# 347077          10
# CA 2144         10
# S.O.C. 14879     9
#                 ..
# 2693             1
# PC 17612         1
# 349233           1
# 349236           1
# 370376           1
# Name: Ticket, Length: 929, dtype: int64

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Pclass                               Name     Sex   Age  \
# 188         1080       3                    Sage, Miss. Ada  female   NaN
# 342         1234       3              Sage, Mr. John George    male   NaN
# 360         1252       3        Sage, Master. William Henry    male  14.5
# 365         1257       3     Sage, Mrs. John (Annie Bullen)  female   NaN
# 188         1080       3                    Sage, Miss. Ada  female   NaN
# 342         1234       3              Sage, Mr. John George    male   NaN
# 360         1252       3        Sage, Master. William Henry    male  14.5
# 365         1257       3     Sage, Mrs. John (Annie Bullen)  female   NaN
# 159          160       3         Sage, Master. Thomas Henry    male   NaN
# 180          181       3       Sage, Miss. Constance Gladys  female   NaN
# 201          202       3                Sage, Mr. Frederick    male   NaN
# 324          325       3           Sage, Mr. George John Jr    male   NaN
# 792          793       3            Sage, Miss. Stella Anna  female   NaN
# 846          847       3           Sage, Mr. Douglas Bullen    male   NaN
# 863          864       3  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked  Survived
# 188      8      2  CA. 2343  69.55   NaN        S       NaN
# 342      1      9  CA. 2343  69.55   NaN        S       NaN
# 360      8      2  CA. 2343  69.55   NaN        S       NaN
# 365      1      9  CA. 2343  69.55   NaN        S       NaN
# 188      8      2  CA. 2343  69.55   NaN        S       NaN
# 342      1      9  CA. 2343  69.55   NaN        S       NaN
# 360      8      2  CA. 2343  69.55   NaN        S       NaN
# 365      1      9  CA. 2343  69.55   NaN        S       NaN
# 159      8      2  CA. 2343  69.55   NaN        S       0.0
# 180      8      2  CA. 2343  69.55   NaN        S       0.0
# 201      8      2  CA. 2343  69.55   NaN        S       0.0
# 324      8      2  CA. 2343  69.55   NaN        S       0.0
# 792      8      2  CA. 2343  69.55   NaN        S       0.0
# 846      8      2  CA. 2343  69.55   NaN        S       0.0
# 863      8      2  CA. 2343  69.55   NaN        S       0.0

# %%
df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df['individual_fare']
# Out:
# 0       7.829200
# 1       3.500000
# 2       9.687500
# 3       8.662500
# 4       4.095833
#          ...
# 886    13.000000
# 887    30.000000
# 888     5.862500
# 889    30.000000
# 890     7.750000
# Name: individual_fare, Length: 1727, dtype: float64

# %%
df['individual_fare'].plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
df[['individual_fare', 'Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1725.000000  1725.000000
# mean         20.829079    33.859145
# std          35.735769    52.784380
# min           0.000000     0.000000
# 25%           7.550000     7.895800
# 50%           8.662500    14.454200
# 75%          24.500000    31.275000
# max         512.329200   512.329200

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived  \
# 0      male  34.5      0      0      330911   7.8292   NaN        Q       NaN
# 1    female  47.0      1      0      363272   7.0000   NaN        S       NaN
# 2      male  62.0      0      0      240276   9.6875   NaN        Q       NaN
# 3      male  27.0      0      0      315154   8.6625   NaN        S       NaN
# 4    female  22.0      1      1     3101298  12.2875   NaN        S       NaN
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 886    male  27.0      0      0      211536  13.0000   NaN        S       0.0
# 887  female  19.0      0      0      112053  30.0000   B42        S       1.0
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S       0.0
# 889    male  26.0      0      0      111369  30.0000  C148        C       1.0
# 890    male  32.0      0      0      370376   7.7500   NaN        Q       0.0
#
#      individual_fare
# 0           7.829200
# 1           3.500000
# 2           9.687500
# 3           8.662500
# 4           4.095833
# ..               ...
# 886        13.000000
# 887        30.000000
# 888         5.862500
# 889        30.000000
# 890         7.750000
#
# [1727 rows x 13 columns]

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived  \
# 0      male  34.5      0      0      330911   7.8292   NaN        Q       NaN
# 1    female  47.0      1      0      363272   7.0000   NaN        S       NaN
# 2      male  62.0      0      0      240276   9.6875   NaN        Q       NaN
# 3      male  27.0      0      0      315154   8.6625   NaN        S       NaN
# 4    female  22.0      1      1     3101298  12.2875   NaN        S       NaN
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 886    male  27.0      0      0      211536  13.0000   NaN        S       0.0
# 887  female  19.0      0      0      112053  30.0000   B42        S       1.0
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S       0.0
# 889    male  26.0      0      0      111369  30.0000  C148        C       1.0
# 890    male  32.0      0      0      370376   7.7500   NaN        Q       0.0
#
#      individual_fare  family_size
# 0           7.829200            1
# 1           3.500000            2
# 2           9.687500            1
# 3           8.662500            1
# 4           4.095833            3
# ..               ...          ...
# 886        13.000000            1
# 887        30.000000            1
# 888         5.862500            4
# 889        30.000000            1
# 890         7.750000            1
#
# [1727 rows x 14 columns]

# %%
# family type
# 1 > alone
# 2-4 > small 
# 5 => large

# %%
def transform_family_size(num):
    if num == 1:
        return 'alone'
    elif num > 1 and num < 5:
        return 'small'
    else:
        return 'large'

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df['family_type']
# Out:
# 0      alone
# 1      small
# 2      alone
# 3      alone
# 4      small
#        ...
# 886    alone
# 887    alone
# 888    small
# 889    alone
# 890    alone
# Name: family_type, Length: 1727, dtype: object

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived  \
# 0      male  34.5      0      0      330911   7.8292   NaN        Q       NaN
# 1    female  47.0      1      0      363272   7.0000   NaN        S       NaN
# 2      male  62.0      0      0      240276   9.6875   NaN        Q       NaN
# 3      male  27.0      0      0      315154   8.6625   NaN        S       NaN
# 4    female  22.0      1      1     3101298  12.2875   NaN        S       NaN
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 886    male  27.0      0      0      211536  13.0000   NaN        S       0.0
# 887  female  19.0      0      0      112053  30.0000   B42        S       1.0
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S       0.0
# 889    male  26.0      0      0      111369  30.0000  C148        C       1.0
# 890    male  32.0      0      0      370376   7.7500   NaN        Q       0.0
#
#      individual_fare  family_size family_type
# 0           7.829200            1       alone
# 1           3.500000            2       small
# 2           9.687500            1       alone
# 3           8.662500            1       alone
# 4           4.095833            3       small
# ..               ...          ...         ...
# 886        13.000000            1       alone
# 887        30.000000            1       alone
# 888         5.862500            4       small
# 889        30.000000            1       alone
# 890         7.750000            1       alone
#
# [1727 rows x 15 columns]

# %%
pd.crosstab(df['Survived'],df['family_type'], normalize='columns') *100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
df['surname']= df['Name'].str.split(',').str.get(0)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived  \
# 0      male  34.5      0      0      330911   7.8292   NaN        Q       NaN
# 1    female  47.0      1      0      363272   7.0000   NaN        S       NaN
# 2      male  62.0      0      0      240276   9.6875   NaN        Q       NaN
# 3      male  27.0      0      0      315154   8.6625   NaN        S       NaN
# 4    female  22.0      1      1     3101298  12.2875   NaN        S       NaN
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 886    male  27.0      0      0      211536  13.0000   NaN        S       0.0
# 887  female  19.0      0      0      112053  30.0000   B42        S       1.0
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S       0.0
# 889    male  26.0      0      0      111369  30.0000  C148        C       1.0
# 890    male  32.0      0      0      370376   7.7500   NaN        Q       0.0
#
#      individual_fare  family_size family_type   surname
# 0           7.829200            1       alone     Kelly
# 1           3.500000            2       small    Wilkes
# 2           9.687500            1       alone     Myles
# 3           8.662500            1       alone      Wirz
# 4           4.095833            3       small  Hirvonen
# ..               ...          ...         ...       ...
# 886        13.000000            1       alone  Montvila
# 887        30.000000            1       alone    Graham
# 888         5.862500            4       small  Johnston
# 889        30.000000            1       alone      Behr
# 890         7.750000            1       alone    Dooley
#
# [1727 rows x 16 columns]

# %%
df['Title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['Title'].value_counts()
# Out:
# Mr.          997
# Miss.        338
# Mrs.         269
# Master.       82
# Rev.          10
# Dr.            9
# Col.           6
# Ms.            3
# Mlle.          2
# Dona.          2
# Major.         2
# the            1
# Capt.          1
# Don.           1
# Sir.           1
# Lady.          1
# Mme.           1
# Jonkheer.      1
# Name: Title, dtype: int64

# %%
df['Cabin'].isnull().sum()
# Out:
# 1341

# %%
df['Cabin'].value_counts().head(15)
# Out:
# B57 B59 B63 B66    8
# C23 C25 C27        8
# F4                 6
# G6                 6
# C78                6
# C101               5
# F2                 5
# C22 C26            5
# D                  5
# A34                5
# F33                5
# E34                5
# C6                 4
# B96 B98            4
# B45                4
# Name: Cabin, dtype: int64

# %%
df['Cabin'].fillna('M', inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# M                  1341
# C23 C25 C27           8
# B57 B59 B63 B66       8
# F4                    6
# C78                   6
#                    ...
# C128                  1
# T                     1
# E40                   1
# C91                   1
# C148                  1
# Name: Cabin, Length: 187, dtype: int64

# %%
df['deck'] = df['Cabin'].str[0]

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived  \
# 0      male  34.5      0      0      330911   7.8292     M        Q       NaN
# 1    female  47.0      1      0      363272   7.0000     M        S       NaN
# 2      male  62.0      0      0      240276   9.6875     M        Q       NaN
# 3      male  27.0      0      0      315154   8.6625     M        S       NaN
# 4    female  22.0      1      1     3101298  12.2875     M        S       NaN
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 886    male  27.0      0      0      211536  13.0000     M        S       0.0
# 887  female  19.0      0      0      112053  30.0000   B42        S       1.0
# 888  female   NaN      1      2  W./C. 6607  23.4500     M        S       0.0
# 889    male  26.0      0      0      111369  30.0000  C148        C       1.0
# 890    male  32.0      0      0      370376   7.7500     M        Q       0.0
#
#      individual_fare  family_size family_type   surname  Title deck
# 0           7.829200            1       alone     Kelly    Mr.    M
# 1           3.500000            2       small    Wilkes   Mrs.    M
# 2           9.687500            1       alone     Myles    Mr.    M
# 3           8.662500            1       alone      Wirz    Mr.    M
# 4           4.095833            3       small  Hirvonen   Mrs.    M
# ..               ...          ...         ...       ...    ...  ...
# 886        13.000000            1       alone  Montvila   Rev.    M
# 887        30.000000            1       alone    Graham  Miss.    B
# 888         5.862500            4       small  Johnston  Miss.    M
# 889        30.000000            1       alone      Behr    Mr.    C
# 890         7.750000            1       alone    Dooley    Mr.    M
#
# [1727 rows x 18 columns]

# %%
df['deck'].value_counts()
# Out:
# M    1341
# C     129
# B      83
# D      59
# E      50
# A      29
# F      29
# G       6
# T       1
# Name: deck, dtype: int64

# %%
pd.crosstab(df['Survived'], df['deck'], normalize='columns')*100
# Out:
# deck              A          B          C          D     E          F     G  \
# Survived
# 0.0       53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1.0       46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# deck              M      T
# Survived
# 0.0       70.014556  100.0
# 1.0       29.985444    0.0

# %%
pd.crosstab(df['deck'], df['Survived'], normalize='index').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='deck'>

# %%
df.corr()['Survived']
# Out:
# PassengerId       -0.005007
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# Fare               0.257307
# Survived           1.000000
# individual_fare    0.221600
# family_size        0.016639
# Name: Survived, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)
